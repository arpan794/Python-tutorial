# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.1

# %% [markdown]
# ### #Pandas Series

# %%
a = [1,3,5]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    3
# 2    5
# dtype: int64

# %%
print(myvar[0])
# Out:
# 1

# %%
a = [1,4,5]
myvar = pd.Series(a, index=["x","y","z"])
print(myvar)
# Out:
# x    1
# y    4
# z    5
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 4

# %%
calories = {"day1": 432,"day2": 456,"day3": 450}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    432
# day2    456
# day3    450
# dtype: int64

# %%
myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    432
# day2    456
# dtype: int64

# %%
mydata = {
      'cars': ["bmw", "volvo","ford"],
       'passings': [3,7,2]
}
myvar = pd.Series(mydata)

print(myvar)
# Out:
# cars        [bmw, volvo, ford]
# passings             [3, 7, 2]
# dtype: object

# %% [markdown]
# ### #DataFrames

# %%
mydata = {
    "cars": ["bmw", "ford", "volvo"],
    "passings": [3,7,2] 
}

myvar = pd.DataFrame(mydata)

print(myvar)

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data, index=[1,2,3])

print(myvar)
# Out:
#    calories  duration
# 1       420        50
# 2       380        40
# 3       390        45

# %%
print(myvar.loc[1])
# Out:
# calories    420
# duration     50
# Name: 1, dtype: int64

# %%
print(myvar.loc[[1,2]])
# Out:
#    calories  duration
# 1       420        50
# 2       380        40

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# created a new csv file from a data frame

# %%
data = {
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 22],
    'city': ['New York', 'London', 'Delhi']
}

df = pd.DataFrame(data)

# Save to CSV
df.to_csv('new_data.csv', index=False)

print("data.csv created successfully!")
# Out:
# data.csv created successfully!

# %% [markdown]
# If you have a large DataFrame with many rows, Pandas will only return the first 5 rows, and the last 5 rows
#
# Print the DataFrame without the to_string() method:

# %%
new_df = pd.read_csv('data.csv')
print(new_df)
# Out:
#        ID       Name  Age  Country  Salary   Department
# 0       1     User_1   62      USA   45834      Finance
# 1       2     User_2   59  Germany   46471           HR
# 2       3     User_3   45   Canada   98883  Engineering
# 3       4     User_4   64   Canada   53933           HR
# 4       5     User_5   56      USA   80861           HR
# ..    ...        ...  ...      ...     ...          ...
# 995   996   User_996   46  Germany   86600      Finance
# 996   997   User_997   59   Canada   99839      Finance
# 997   998   User_998   20  Germany   50327        Sales
# 998   999   User_999   34       UK   86632           HR
# 999  1000  User_1000   21       UK  109839    Marketing
#
# [1000 rows x 6 columns]

# %% [markdown]
# with to_string method

# %%
new_df = pd.read_csv('data.csv')
print(new_df.to_string())
# Out:
#        ID       Name  Age  Country  Salary   Department
# 0       1     User_1   62      USA   45834      Finance
# 1       2     User_2   59  Germany   46471           HR
# 969   970   User_970   46   Canada  101692  Engineering
# 970   971   User_971   30   Canada   47469  Engineering
# 971   972   User_972   43      USA   73466  Engineering
# 972   973   User_973   63       UK   75718  Engineering
# 973   974   User_974   35    India   33367  Engineering
# 974   975   User_975   52   Canada  105302    Marketing
# 975   976   User_976   18   Canada   40128    Marketing
# 976   977   User_977   26      USA  100428    Marketing
# 977   978   User_978   46    India   56962           HR
# 978   979   User_979   39      USA   89579        Sales
# 979   980   User_980   26    India  104585    Marketing
# 980   981   User_981   61   Canada   59115    Marketing
# 981   982   User_982   18  Germany   41246      Finance
# 982   983   User_983   51      USA   86881  Engineering
# 983   984   User_984   30    India   90280           HR
# 984   985   User_985   55       UK  110383    Marketing
# 985   986   User_986   45   Canada  115179  Engineering
# 986   987   User_987   38   Canada   80775        Sales
# 987   988   User_988   41      USA  113307        Sales
# 988   989   User_989   49    India   30593           HR
# 989   990   User_990   19   Canada   61574        Sales
# 990   991   User_991   60       UK   43962      Finance
# 991   992   User_992   64   Canada   57053        Sales
# 992   993   User_993   37       UK   84932        Sales
# 993   994   User_994   47       UK   98061      Finance
# 994   995   User_995   23  Germany   81924           HR
# 995   996   User_996   46  Germany   86600      Finance
# 996   997   User_997   59   Canada   99839      Finance
# 997   998   User_998   20  Germany   50327        Sales
# 998   999   User_999   34       UK   86632           HR
# 999  1000  User_1000   21       UK  109839    Marketing

# %% [markdown]
# You can check your system's maximum rows

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# we can change the max row by this cmd

# %%
# pd.options.display.max_rows = 80

df = pd.read_csv('data.csv')

print(df)

# %% [markdown]
# Load the JSON file into a DataFrame:

# %%
df = pd.read_json('data.json')

print(df.to_string())
# Out:
#        id       name                 email  age  is_active                                    preferences
# 0       1     User_1     user1@example.com   52      False    {'newsletter': True, 'notifications': True}
# 1       2     User_2     user2@example.com   26       True    {'newsletter': True, 'notifications': True}
# 2       3     User_3     user3@example.com   21      False    {'newsletter': True, 'notifications': True}
# 3       4     User_4     user4@example.com   18      False  {'newsletter': False, 'notifications': False}
# 4       5     User_5     user5@example.com   28      False   {'newsletter': False, 'notifications': True}
# 5       6     User_6     user6@example.com   26      False   {'newsletter': True, 'notifications': False}
# 6       7     User_7     user7@example.com   21      False   {'newsletter': True, 'notifications': False}
# 7       8     User_8     user8@example.com   47       True  {'newsletter': False, 'notifications': False}
# 8       9     User_9     user9@example.com   33      False   {'newsletter': False, 'notifications': True}
# 9      10    User_10    user10@example.com   50      False    {'newsletter': True, 'notifications': True}
# 10     11    User_11    user11@example.com   18      False   {'newsletter': False, 'notifications': True}
# 11     12    User_12    user12@example.com   50      False   {'newsletter': True, 'notifications': False}
# 12     13    User_13    user13@example.com   50       True  {'newsletter': False, 'notifications': False}
# 13     14    User_14    user14@example.com   35       True   {'newsletter': False, 'notifications': True}
# 14     15    User_15    user15@example.com   53      False  {'newsletter': False, 'notifications': False}
# 15     16    User_16    user16@example.com   44      False  {'newsletter': False, 'notifications': False}
# 16     17    User_17    user17@example.com   32      False  {'newsletter': False, 'notifications': False}
# 17     18    User_18    user18@example.com   41      False   {'newsletter': False, 'notifications': True}
# 18     19    User_19    user19@example.com   22      False  {'newsletter': False, 'notifications': False}
# 19     20    User_20    user20@example.com   42      False  {'newsletter': False, 'notifications': False}
# 20     21    User_21    user21@example.com   49       True    {'newsletter': True, 'notifications': True}
# 21     22    User_22    user22@example.com   40       True   {'newsletter': True, 'notifications': False}
# 22     23    User_23    user23@example.com   55      False   {'newsletter': False, 'notifications': True}
# 23     24    User_24    user24@example.com   41       True    {'newsletter': True, 'notifications': True}
# 24     25    User_25    user25@example.com   52       True  {'newsletter': False, 'notifications': False}
# 25     26    User_26    user26@example.com   26      False    {'newsletter': True, 'notifications': True}
# 26     27    User_27    user27@example.com   47      False   {'newsletter': False, 'notifications': True}
# 27     28    User_28    user28@example.com   35      False   {'newsletter': True, 'notifications': False}
# 28     29    User_29    user29@example.com   23       True   {'newsletter': False, 'notifications': True}
# 29     30    User_30    user30@example.com   21       True   {'newsletter': False, 'notifications': True}
# 30     31    User_31    user31@example.com   45       True   {'newsletter': True, 'notifications': False}
# 31     32    User_32    user32@example.com   49      False   {'newsletter': True, 'notifications': False}
# 32     33    User_33    user33@example.com   57      False   {'newsletter': False, 'notifications': True}
# 33     34    User_34    user34@example.com   45      False    {'newsletter': True, 'notifications': True}
# 34     35    User_35    user35@example.com   40      False    {'newsletter': True, 'notifications': True}
# 35     36    User_36    user36@example.com   51       True   {'newsletter': False, 'notifications': True}
# 36     37    User_37    user37@example.com   38      False  {'newsletter': False, 'notifications': False}
# 37     38    User_38    user38@example.com   39       True   {'newsletter': True, 'notifications': False}
# 38     39    User_39    user39@example.com   51      False  {'newsletter': False, 'notifications': False}
# 39     40    User_40    user40@example.com   46       True  {'newsletter': False, 'notifications': False}
# 40     41    User_41    user41@example.com   38      False   {'newsletter': True, 'notifications': False}
# 41     42    User_42    user42@example.com   45       True    {'newsletter': True, 'notifications': True}
# 42     43    User_43    user43@example.com   47       True  {'newsletter': False, 'notifications': False}
# 43     44    User_44    user44@example.com   40       True   {'newsletter': False, 'notifications': True}
# 44     45    User_45    user45@example.com   50       True   {'newsletter': False, 'notifications': True}
# 45     46    User_46    user46@example.com   38      False    {'newsletter': True, 'notifications': True}
# 46     47    User_47    user47@example.com   21      False   {'newsletter': True, 'notifications': False}
# 47     48    User_48    user48@example.com   34      False   {'newsletter': True, 'notifications': False}
# 48     49    User_49    user49@example.com   37      False   {'newsletter': True, 'notifications': False}
# 49     50    User_50    user50@example.com   25      False   {'newsletter': True, 'notifications': False}
# 50     51    User_51    user51@example.com   24       True   {'newsletter': False, 'notifications': True}
# 51     52    User_52    user52@example.com   35      False  {'newsletter': False, 'notifications': False}
# 52     53    User_53    user53@example.com   38       True   {'newsletter': True, 'notifications': False}
# 53     54    User_54    user54@example.com   39      False   {'newsletter': False, 'notifications': True}
# 54     55    User_55    user55@example.com   47       True   {'newsletter': True, 'notifications': False}
# 55     56    User_56    user56@example.com   50       True    {'newsletter': True, 'notifications': True}
# 56     57    User_57    user57@example.com   43       True  {'newsletter': False, 'notifications': False}
# 57     58    User_58    user58@example.com   38       True  {'newsletter': False, 'notifications': False}
# 58     59    User_59    user59@example.com   59      False  {'newsletter': False, 'notifications': False}
# 59     60    User_60    user60@example.com   23      False  {'newsletter': False, 'notifications': False}
# 60     61    User_61    user61@example.com   54      False  {'newsletter': False, 'notifications': False}
# 61     62    User_62    user62@example.com   56      False   {'newsletter': True, 'notifications': False}
# 62     63    User_63    user63@example.com   31      False  {'newsletter': False, 'notifications': False}
# 63     64    User_64    user64@example.com   22       True   {'newsletter': True, 'notifications': False}
# 64     65    User_65    user65@example.com   23      False  {'newsletter': False, 'notifications': False}
# 65     66    User_66    user66@example.com   44       True   {'newsletter': True, 'notifications': False}
# 66     67    User_67    user67@example.com   32      False   {'newsletter': True, 'notifications': False}
# 67     68    User_68    user68@example.com   43      False    {'newsletter': True, 'notifications': True}
# 68     69    User_69    user69@example.com   42       True   {'newsletter': False, 'notifications': True}
# 69     70    User_70    user70@example.com   53      False  {'newsletter': False, 'notifications': False}
# 70     71    User_71    user71@example.com   27      False  {'newsletter': False, 'notifications': False}
# 71     72    User_72    user72@example.com   22      False  {'newsletter': False, 'notifications': False}
# 72     73    User_73    user73@example.com   38       True    {'newsletter': True, 'notifications': True}
# 73     74    User_74    user74@example.com   34       True    {'newsletter': True, 'notifications': True}
# 74     75    User_75    user75@example.com   59      False   {'newsletter': True, 'notifications': False}
# 75     76    User_76    user76@example.com   50      False   {'newsletter': True, 'notifications': False}
# 76     77    User_77    user77@example.com   23       True   {'newsletter': True, 'notifications': False}
# 77     78    User_78    user78@example.com   19       True    {'newsletter': True, 'notifications': True}
# 78     79    User_79    user79@example.com   22       True    {'newsletter': True, 'notifications': True}
# 79     80    User_80    user80@example.com   22       True   {'newsletter': False, 'notifications': True}
# 80     81    User_81    user81@example.com   59       True    {'newsletter': True, 'notifications': True}
# 81     82    User_82    user82@example.com   21      False    {'newsletter': True, 'notifications': True}
# 82     83    User_83    user83@example.com   32      False   {'newsletter': True, 'notifications': False}
# 83     84    User_84    user84@example.com   47      False   {'newsletter': False, 'notifications': True}
# 84     85    User_85    user85@example.com   40      False    {'newsletter': True, 'notifications': True}
# 85     86    User_86    user86@example.com   37       True    {'newsletter': True, 'notifications': True}
# 86     87    User_87    user87@example.com   24       True    {'newsletter': True, 'notifications': True}
# 87     88    User_88    user88@example.com   47       True  {'newsletter': False, 'notifications': False}
# 88     89    User_89    user89@example.com   19       True   {'newsletter': False, 'notifications': True}
# 89     90    User_90    user90@example.com   52      False  {'newsletter': False, 'notifications': False}
# 90     91    User_91    user91@example.com   53       True   {'newsletter': True, 'notifications': False}
# 91     92    User_92    user92@example.com   59       True  {'newsletter': False, 'notifications': False}
# 92     93    User_93    user93@example.com   45       True  {'newsletter': False, 'notifications': False}
# 93     94    User_94    user94@example.com   22       True    {'newsletter': True, 'notifications': True}
# 94     95    User_95    user95@example.com   43       True   {'newsletter': False, 'notifications': True}
# 95     96    User_96    user96@example.com   41       True  {'newsletter': False, 'notifications': False}
# 96     97    User_97    user97@example.com   34       True   {'newsletter': False, 'notifications': True}
# 97     98    User_98    user98@example.com   37       True    {'newsletter': True, 'notifications': True}
# 98     99    User_99    user99@example.com   57      False    {'newsletter': True, 'notifications': True}
# 99    100   User_100   user100@example.com   28       True  {'newsletter': False, 'notifications': False}
# 100   101   User_101   user101@example.com   48       True  {'newsletter': False, 'notifications': False}
# 101   102   User_102   user102@example.com   46      False   {'newsletter': True, 'notifications': False}
# 102   103   User_103   user103@example.com   26      False    {'newsletter': True, 'notifications': True}
# 103   104   User_104   user104@example.com   29      False    {'newsletter': True, 'notifications': True}
# 104   105   User_105   user105@example.com   60       True   {'newsletter': False, 'notifications': True}
# 105   106   User_106   user106@example.com   18      False   {'newsletter': True, 'notifications': False}
# 106   107   User_107   user107@example.com   39      False   {'newsletter': False, 'notifications': True}
# 107   108   User_108   user108@example.com   33       True    {'newsletter': True, 'notifications': True}
# 108   109   User_109   user109@example.com   51       True  {'newsletter': False, 'notifications': False}
# 109   110   User_110   user110@example.com   54      False    {'newsletter': True, 'notifications': True}
# 110   111   User_111   user111@example.com   50       True   {'newsletter': False, 'notifications': True}
# 111   112   User_112   user112@example.com   39       True  {'newsletter': False, 'notifications': False}
# 112   113   User_113   user113@example.com   55       True  {'newsletter': False, 'notifications': False}
# 113   114   User_114   user114@example.com   35      False    {'newsletter': True, 'notifications': True}
# 114   115   User_115   user115@example.com   24       True   {'newsletter': True, 'notifications': False}
# 115   116   User_116   user116@example.com   26      False   {'newsletter': True, 'notifications': False}
# 116   117   User_117   user117@example.com   60      False    {'newsletter': True, 'notifications': True}
# 117   118   User_118   user118@example.com   52       True  {'newsletter': False, 'notifications': False}
# 118   119   User_119   user119@example.com   31      False   {'newsletter': True, 'notifications': False}
# 119   120   User_120   user120@example.com   27      False   {'newsletter': False, 'notifications': True}
# 120   121   User_121   user121@example.com   28       True  {'newsletter': False, 'notifications': False}
# 121   122   User_122   user122@example.com   28      False  {'newsletter': False, 'notifications': False}
# 122   123   User_123   user123@example.com   22       True    {'newsletter': True, 'notifications': True}
# 123   124   User_124   user124@example.com   55       True  {'newsletter': False, 'notifications': False}
# 124   125   User_125   user125@example.com   45      False   {'newsletter': False, 'notifications': True}
# 125   126   User_126   user126@example.com   26       True   {'newsletter': True, 'notifications': False}
# 126   127   User_127   user127@example.com   24      False   {'newsletter': True, 'notifications': False}
# 127   128   User_128   user128@example.com   54      False  {'newsletter': False, 'notifications': False}
# 128   129   User_129   user129@example.com   22      False   {'newsletter': False, 'notifications': True}
# 129   130   User_130   user130@example.com   35      False   {'newsletter': False, 'notifications': True}
# 130   131   User_131   user131@example.com   26       True  {'newsletter': False, 'notifications': False}
# 131   132   User_132   user132@example.com   25       True  {'newsletter': False, 'notifications': False}
# 132   133   User_133   user133@example.com   22      False  {'newsletter': False, 'notifications': False}
# 133   134   User_134   user134@example.com   57       True   {'newsletter': True, 'notifications': False}
# 134   135   User_135   user135@example.com   46      False   {'newsletter': False, 'notifications': True}
# 135   136   User_136   user136@example.com   55      False   {'newsletter': False, 'notifications': True}
# 136   137   User_137   user137@example.com   28      False   {'newsletter': False, 'notifications': True}
# 137   138   User_138   user138@example.com   45       True   {'newsletter': True, 'notifications': False}
# 138   139   User_139   user139@example.com   33       True   {'newsletter': False, 'notifications': True}
# 139   140   User_140   user140@example.com   43       True   {'newsletter': False, 'notifications': True}
# 140   141   User_141   user141@example.com   34       True  {'newsletter': False, 'notifications': False}
# 141   142   User_142   user142@example.com   33      False   {'newsletter': True, 'notifications': False}
# 142   143   User_143   user143@example.com   51       True   {'newsletter': False, 'notifications': True}
# 143   144   User_144   user144@example.com   28      False  {'newsletter': False, 'notifications': False}
# 144   145   User_145   user145@example.com   26       True  {'newsletter': False, 'notifications': False}
# 145   146   User_146   user146@example.com   40      False    {'newsletter': True, 'notifications': True}
# 146   147   User_147   user147@example.com   46       True    {'newsletter': True, 'notifications': True}
# 147   148   User_148   user148@example.com   19       True   {'newsletter': False, 'notifications': True}
# 148   149   User_149   user149@example.com   34       True   {'newsletter': True, 'notifications': False}
# 149   150   User_150   user150@example.com   41      False  {'newsletter': False, 'notifications': False}
# 150   151   User_151   user151@example.com   50       True   {'newsletter': False, 'notifications': True}
# 151   152   User_152   user152@example.com   22      False    {'newsletter': True, 'notifications': True}
# 152   153   User_153   user153@example.com   52       True  {'newsletter': False, 'notifications': False}
# 153   154   User_154   user154@example.com   25      False   {'newsletter': True, 'notifications': False}
# 154   155   User_155   user155@example.com   52      False    {'newsletter': True, 'notifications': True}
# 155   156   User_156   user156@example.com   50      False  {'newsletter': False, 'notifications': False}
# 156   157   User_157   user157@example.com   42      False   {'newsletter': True, 'notifications': False}
# 157   158   User_158   user158@example.com   58      False   {'newsletter': False, 'notifications': True}
# 158   159   User_159   user159@example.com   33      False    {'newsletter': True, 'notifications': True}
# 159   160   User_160   user160@example.com   39      False  {'newsletter': False, 'notifications': False}
# 160   161   User_161   user161@example.com   41      False   {'newsletter': True, 'notifications': False}
# 161   162   User_162   user162@example.com   27      False  {'newsletter': False, 'notifications': False}
# 162   163   User_163   user163@example.com   42       True   {'newsletter': True, 'notifications': False}
# 163   164   User_164   user164@example.com   34       True    {'newsletter': True, 'notifications': True}
# 164   165   User_165   user165@example.com   58       True  {'newsletter': False, 'notifications': False}
# 165   166   User_166   user166@example.com   24      False   {'newsletter': False, 'notifications': True}
# 166   167   User_167   user167@example.com   26       True    {'newsletter': True, 'notifications': True}
# 167   168   User_168   user168@example.com   25       True    {'newsletter': True, 'notifications': True}
# 168   169   User_169   user169@example.com   27       True   {'newsletter': True, 'notifications': False}
# 169   170   User_170   user170@example.com   35      False   {'newsletter': False, 'notifications': True}
# 170   171   User_171   user171@example.com   31       True  {'newsletter': False, 'notifications': False}
# 171   172   User_172   user172@example.com   25      False   {'newsletter': True, 'notifications': False}
# 172   173   User_173   user173@example.com   23       True   {'newsletter': False, 'notifications': True}
# 173   174   User_174   user174@example.com   35      False   {'newsletter': True, 'notifications': False}
# 174   175   User_175   user175@example.com   23      False    {'newsletter': True, 'notifications': True}
# 175   176   User_176   user176@example.com   45      False   {'newsletter': True, 'notifications': False}
# 176   177   User_177   user177@example.com   39       True   {'newsletter': True, 'notifications': False}
# 177   178   User_178   user178@example.com   44       True  {'newsletter': False, 'notifications': False}
# 178   179   User_179   user179@example.com   26       True   {'newsletter': True, 'notifications': False}
# 179   180   User_180   user180@example.com   51       True   {'newsletter': False, 'notifications': True}
# 180   181   User_181   user181@example.com   46       True   {'newsletter': True, 'notifications': False}
# 181   182   User_182   user182@example.com   58      False    {'newsletter': True, 'notifications': True}
# 182   183   User_183   user183@example.com   40      False    {'newsletter': True, 'notifications': True}
# 183   184   User_184   user184@example.com   25       True   {'newsletter': True, 'notifications': False}
# 184   185   User_185   user185@example.com   53       True   {'newsletter': True, 'notifications': False}
# 185   186   User_186   user186@example.com   20      False    {'newsletter': True, 'notifications': True}
# 186   187   User_187   user187@example.com   23       True   {'newsletter': True, 'notifications': False}
# 187   188   User_188   user188@example.com   18       True    {'newsletter': True, 'notifications': True}
# 188   189   User_189   user189@example.com   51       True  {'newsletter': False, 'notifications': False}
# 189   190   User_190   user190@example.com   57      False   {'newsletter': False, 'notifications': True}
# 190   191   User_191   user191@example.com   47      False    {'newsletter': True, 'notifications': True}
# 191   192   User_192   user192@example.com   20       True   {'newsletter': False, 'notifications': True}
# 192   193   User_193   user193@example.com   53      False   {'newsletter': False, 'notifications': True}
# 193   194   User_194   user194@example.com   50      False   {'newsletter': False, 'notifications': True}
# 194   195   User_195   user195@example.com   34      False  {'newsletter': False, 'notifications': False}
# 195   196   User_196   user196@example.com   31       True   {'newsletter': True, 'notifications': False}
# 196   197   User_197   user197@example.com   22      False   {'newsletter': False, 'notifications': True}
# 197   198   User_198   user198@example.com   28       True  {'newsletter': False, 'notifications': False}
# 198   199   User_199   user199@example.com   34      False  {'newsletter': False, 'notifications': False}
# 199   200   User_200   user200@example.com   60       True    {'newsletter': True, 'notifications': True}
# 200   201   User_201   user201@example.com   32      False    {'newsletter': True, 'notifications': True}
# 201   202   User_202   user202@example.com   25       True    {'newsletter': True, 'notifications': True}
# 202   203   User_203   user203@example.com   35       True  {'newsletter': False, 'notifications': False}
# 203   204   User_204   user204@example.com   26       True   {'newsletter': True, 'notifications': False}
# 204   205   User_205   user205@example.com   60       True  {'newsletter': False, 'notifications': False}
# 205   206   User_206   user206@example.com   39      False   {'newsletter': False, 'notifications': True}
# 206   207   User_207   user207@example.com   48       True   {'newsletter': False, 'notifications': True}
# 207   208   User_208   user208@example.com   58      False    {'newsletter': True, 'notifications': True}
# 208   209   User_209   user209@example.com   50       True   {'newsletter': False, 'notifications': True}
# 209   210   User_210   user210@example.com   28       True   {'newsletter': False, 'notifications': True}
# 210   211   User_211   user211@example.com   57       True  {'newsletter': False, 'notifications': False}
# 211   212   User_212   user212@example.com   18      False   {'newsletter': False, 'notifications': True}
# 212   213   User_213   user213@example.com   60       True  {'newsletter': False, 'notifications': False}
# 213   214   User_214   user214@example.com   34       True   {'newsletter': True, 'notifications': False}
# 214   215   User_215   user215@example.com   27      False   {'newsletter': False, 'notifications': True}
# 215   216   User_216   user216@example.com   36       True   {'newsletter': True, 'notifications': False}
# 216   217   User_217   user217@example.com   44       True  {'newsletter': False, 'notifications': False}
# 217   218   User_218   user218@example.com   44       True    {'newsletter': True, 'notifications': True}
# 218   219   User_219   user219@example.com   50      False   {'newsletter': False, 'notifications': True}
# 219   220   User_220   user220@example.com   33      False    {'newsletter': True, 'notifications': True}
# 220   221   User_221   user221@example.com   57      False   {'newsletter': True, 'notifications': False}
# 221   222   User_222   user222@example.com   20       True    {'newsletter': True, 'notifications': True}
# 222   223   User_223   user223@example.com   38       True  {'newsletter': False, 'notifications': False}
# 223   224   User_224   user224@example.com   58      False   {'newsletter': True, 'notifications': False}
# 224   225   User_225   user225@example.com   54      False   {'newsletter': False, 'notifications': True}
# 225   226   User_226   user226@example.com   45       True   {'newsletter': True, 'notifications': False}
# 226   227   User_227   user227@example.com   58       True  {'newsletter': False, 'notifications': False}
# 227   228   User_228   user228@example.com   58      False   {'newsletter': True, 'notifications': False}
# 228   229   User_229   user229@example.com   38      False    {'newsletter': True, 'notifications': True}
# 229   230   User_230   user230@example.com   33       True   {'newsletter': True, 'notifications': False}
# 230   231   User_231   user231@example.com   20      False   {'newsletter': True, 'notifications': False}
# 231   232   User_232   user232@example.com   46      False   {'newsletter': True, 'notifications': False}
# 232   233   User_233   user233@example.com   52      False    {'newsletter': True, 'notifications': True}
# 233   234   User_234   user234@example.com   59       True   {'newsletter': True, 'notifications': False}
# 234   235   User_235   user235@example.com   45      False   {'newsletter': False, 'notifications': True}
# 235   236   User_236   user236@example.com   52       True    {'newsletter': True, 'notifications': True}
# 236   237   User_237   user237@example.com   24       True  {'newsletter': False, 'notifications': False}
# 237   238   User_238   user238@example.com   58      False  {'newsletter': False, 'notifications': False}
# 238   239   User_239   user239@example.com   39       True   {'newsletter': True, 'notifications': False}
# 239   240   User_240   user240@example.com   59       True  {'newsletter': False, 'notifications': False}
# 240   241   User_241   user241@example.com   27      False  {'newsletter': False, 'notifications': False}
# 241   242   User_242   user242@example.com   32       True    {'newsletter': True, 'notifications': True}
# 242   243   User_243   user243@example.com   49      False   {'newsletter': False, 'notifications': True}
# 243   244   User_244   user244@example.com   34      False  {'newsletter': False, 'notifications': False}
# 244   245   User_245   user245@example.com   41      False   {'newsletter': True, 'notifications': False}
# 245   246   User_246   user246@example.com   52       True   {'newsletter': True, 'notifications': False}
# 246   247   User_247   user247@example.com   36      False   {'newsletter': False, 'notifications': True}
# 247   248   User_248   user248@example.com   23      False  {'newsletter': False, 'notifications': False}
# 248   249   User_249   user249@example.com   46       True   {'newsletter': True, 'notifications': False}
# 249   250   User_250   user250@example.com   25       True   {'newsletter': False, 'notifications': True}
# 250   251   User_251   user251@example.com   29       True   {'newsletter': True, 'notifications': False}
# 251   252   User_252   user252@example.com   44       True   {'newsletter': True, 'notifications': False}
# 252   253   User_253   user253@example.com   54       True    {'newsletter': True, 'notifications': True}
# 253   254   User_254   user254@example.com   19       True   {'newsletter': True, 'notifications': False}
# 254   255   User_255   user255@example.com   25      False   {'newsletter': True, 'notifications': False}
# 255   256   User_256   user256@example.com   60      False  {'newsletter': False, 'notifications': False}
# 256   257   User_257   user257@example.com   57      False   {'newsletter': True, 'notifications': False}
# 257   258   User_258   user258@example.com   24       True    {'newsletter': True, 'notifications': True}
# 258   259   User_259   user259@example.com   23       True   {'newsletter': True, 'notifications': False}
# 259   260   User_260   user260@example.com   34       True   {'newsletter': True, 'notifications': False}
# 260   261   User_261   user261@example.com   60       True    {'newsletter': True, 'notifications': True}
# 261   262   User_262   user262@example.com   40       True  {'newsletter': False, 'notifications': False}
# 262   263   User_263   user263@example.com   24       True   {'newsletter': False, 'notifications': True}
# 263   264   User_264   user264@example.com   35      False    {'newsletter': True, 'notifications': True}
# 264   265   User_265   user265@example.com   18       True    {'newsletter': True, 'notifications': True}
# 265   266   User_266   user266@example.com   51      False   {'newsletter': False, 'notifications': True}
# 266   267   User_267   user267@example.com   54      False    {'newsletter': True, 'notifications': True}
# 267   268   User_268   user268@example.com   35       True   {'newsletter': True, 'notifications': False}
# 268   269   User_269   user269@example.com   31       True    {'newsletter': True, 'notifications': True}
# 269   270   User_270   user270@example.com   33       True  {'newsletter': False, 'notifications': False}
# 270   271   User_271   user271@example.com   41      False   {'newsletter': False, 'notifications': True}
# 271   272   User_272   user272@example.com   44      False   {'newsletter': False, 'notifications': True}
# 272   273   User_273   user273@example.com   50       True   {'newsletter': True, 'notifications': False}
# 273   274   User_274   user274@example.com   19      False   {'newsletter': False, 'notifications': True}
# 274   275   User_275   user275@example.com   34      False   {'newsletter': True, 'notifications': False}
# 275   276   User_276   user276@example.com   50      False  {'newsletter': False, 'notifications': False}
# 276   277   User_277   user277@example.com   20      False   {'newsletter': True, 'notifications': False}
# 277   278   User_278   user278@example.com   26      False   {'newsletter': False, 'notifications': True}
# 278   279   User_279   user279@example.com   51      False    {'newsletter': True, 'notifications': True}
# 279   280   User_280   user280@example.com   53      False  {'newsletter': False, 'notifications': False}
# 280   281   User_281   user281@example.com   58       True   {'newsletter': False, 'notifications': True}
# 281   282   User_282   user282@example.com   24       True    {'newsletter': True, 'notifications': True}
# 282   283   User_283   user283@example.com   52       True   {'newsletter': False, 'notifications': True}
# 283   284   User_284   user284@example.com   60      False   {'newsletter': True, 'notifications': False}
# 284   285   User_285   user285@example.com   22      False  {'newsletter': False, 'notifications': False}
# 285   286   User_286   user286@example.com   38      False    {'newsletter': True, 'notifications': True}
# 286   287   User_287   user287@example.com   37       True  {'newsletter': False, 'notifications': False}
# 287   288   User_288   user288@example.com   42      False  {'newsletter': False, 'notifications': False}
# 288   289   User_289   user289@example.com   60      False  {'newsletter': False, 'notifications': False}
# 289   290   User_290   user290@example.com   25      False   {'newsletter': True, 'notifications': False}
# 290   291   User_291   user291@example.com   48      False   {'newsletter': False, 'notifications': True}
# 291   292   User_292   user292@example.com   22       True    {'newsletter': True, 'notifications': True}
# 292   293   User_293   user293@example.com   31       True   {'newsletter': True, 'notifications': False}
# 293   294   User_294   user294@example.com   20       True    {'newsletter': True, 'notifications': True}
# 294   295   User_295   user295@example.com   19       True   {'newsletter': False, 'notifications': True}
# 295   296   User_296   user296@example.com   27      False  {'newsletter': False, 'notifications': False}
# 296   297   User_297   user297@example.com   23       True    {'newsletter': True, 'notifications': True}
# 297   298   User_298   user298@example.com   55       True  {'newsletter': False, 'notifications': False}
# 298   299   User_299   user299@example.com   55       True  {'newsletter': False, 'notifications': False}
# 299   300   User_300   user300@example.com   18       True   {'newsletter': True, 'notifications': False}
# 300   301   User_301   user301@example.com   46       True   {'newsletter': False, 'notifications': True}
# 301   302   User_302   user302@example.com   49      False   {'newsletter': False, 'notifications': True}
# 302   303   User_303   user303@example.com   50      False  {'newsletter': False, 'notifications': False}
# 303   304   User_304   user304@example.com   43       True   {'newsletter': True, 'notifications': False}
# 304   305   User_305   user305@example.com   46      False   {'newsletter': True, 'notifications': False}
# 305   306   User_306   user306@example.com   29       True   {'newsletter': True, 'notifications': False}
# 306   307   User_307   user307@example.com   60      False   {'newsletter': True, 'notifications': False}
# 307   308   User_308   user308@example.com   55       True    {'newsletter': True, 'notifications': True}
# 308   309   User_309   user309@example.com   20      False   {'newsletter': False, 'notifications': True}
# 309   310   User_310   user310@example.com   58      False  {'newsletter': False, 'notifications': False}
# 310   311   User_311   user311@example.com   55       True   {'newsletter': True, 'notifications': False}
# 311   312   User_312   user312@example.com   56      False   {'newsletter': True, 'notifications': False}
# 312   313   User_313   user313@example.com   48      False   {'newsletter': False, 'notifications': True}
# 313   314   User_314   user314@example.com   53      False   {'newsletter': True, 'notifications': False}
# 314   315   User_315   user315@example.com   24       True    {'newsletter': True, 'notifications': True}
# 315   316   User_316   user316@example.com   49       True  {'newsletter': False, 'notifications': False}
# 316   317   User_317   user317@example.com   44      False   {'newsletter': False, 'notifications': True}
# 317   318   User_318   user318@example.com   33       True    {'newsletter': True, 'notifications': True}
# 318   319   User_319   user319@example.com   38      False   {'newsletter': False, 'notifications': True}
# 319   320   User_320   user320@example.com   48       True  {'newsletter': False, 'notifications': False}
# 320   321   User_321   user321@example.com   53       True  {'newsletter': False, 'notifications': False}
# 321   322   User_322   user322@example.com   31       True   {'newsletter': True, 'notifications': False}
# 322   323   User_323   user323@example.com   33       True    {'newsletter': True, 'notifications': True}
# 323   324   User_324   user324@example.com   44      False   {'newsletter': True, 'notifications': False}
# 324   325   User_325   user325@example.com   40      False    {'newsletter': True, 'notifications': True}
# 325   326   User_326   user326@example.com   37      False   {'newsletter': True, 'notifications': False}
# 326   327   User_327   user327@example.com   25       True  {'newsletter': False, 'notifications': False}
# 327   328   User_328   user328@example.com   56       True   {'newsletter': True, 'notifications': False}
# 328   329   User_329   user329@example.com   56      False    {'newsletter': True, 'notifications': True}
# 329   330   User_330   user330@example.com   24      False   {'newsletter': False, 'notifications': True}
# 330   331   User_331   user331@example.com   21       True   {'newsletter': False, 'notifications': True}
# 331   332   User_332   user332@example.com   54       True  {'newsletter': False, 'notifications': False}
# 332   333   User_333   user333@example.com   54       True   {'newsletter': False, 'notifications': True}
# 333   334   User_334   user334@example.com   21       True   {'newsletter': True, 'notifications': False}
# 334   335   User_335   user335@example.com   52      False  {'newsletter': False, 'notifications': False}
# 335   336   User_336   user336@example.com   19       True    {'newsletter': True, 'notifications': True}
# 336   337   User_337   user337@example.com   24      False   {'newsletter': True, 'notifications': False}
# 337   338   User_338   user338@example.com   22       True   {'newsletter': False, 'notifications': True}
# 338   339   User_339   user339@example.com   26      False    {'newsletter': True, 'notifications': True}
# 339   340   User_340   user340@example.com   46      False    {'newsletter': True, 'notifications': True}
# 340   341   User_341   user341@example.com   59       True  {'newsletter': False, 'notifications': False}
# 341   342   User_342   user342@example.com   41      False   {'newsletter': False, 'notifications': True}
# 342   343   User_343   user343@example.com   50      False    {'newsletter': True, 'notifications': True}
# 343   344   User_344   user344@example.com   24       True  {'newsletter': False, 'notifications': False}
# 344   345   User_345   user345@example.com   57       True  {'newsletter': False, 'notifications': False}
# 345   346   User_346   user346@example.com   30       True   {'newsletter': True, 'notifications': False}
# 346   347   User_347   user347@example.com   51      False   {'newsletter': True, 'notifications': False}
# 347   348   User_348   user348@example.com   53       True   {'newsletter': True, 'notifications': False}
# 348   349   User_349   user349@example.com   30      False    {'newsletter': True, 'notifications': True}
# 349   350   User_350   user350@example.com   58      False    {'newsletter': True, 'notifications': True}
# 350   351   User_351   user351@example.com   49       True   {'newsletter': True, 'notifications': False}
# 351   352   User_352   user352@example.com   57      False  {'newsletter': False, 'notifications': False}
# 352   353   User_353   user353@example.com   51      False    {'newsletter': True, 'notifications': True}
# 353   354   User_354   user354@example.com   52       True  {'newsletter': False, 'notifications': False}
# 354   355   User_355   user355@example.com   31      False    {'newsletter': True, 'notifications': True}
# 355   356   User_356   user356@example.com   49      False  {'newsletter': False, 'notifications': False}
# 356   357   User_357   user357@example.com   41      False   {'newsletter': True, 'notifications': False}
# 357   358   User_358   user358@example.com   50      False   {'newsletter': True, 'notifications': False}
# 358   359   User_359   user359@example.com   43      False    {'newsletter': True, 'notifications': True}
# 359   360   User_360   user360@example.com   32      False   {'newsletter': False, 'notifications': True}
# 360   361   User_361   user361@example.com   49       True   {'newsletter': True, 'notifications': False}
# 361   362   User_362   user362@example.com   27      False    {'newsletter': True, 'notifications': True}
# 362   363   User_363   user363@example.com   53       True    {'newsletter': True, 'notifications': True}
# 363   364   User_364   user364@example.com   49      False   {'newsletter': True, 'notifications': False}
# 364   365   User_365   user365@example.com   42       True   {'newsletter': False, 'notifications': True}
# 365   366   User_366   user366@example.com   51      False  {'newsletter': False, 'notifications': False}
# 366   367   User_367   user367@example.com   26      False    {'newsletter': True, 'notifications': True}
# 367   368   User_368   user368@example.com   22       True  {'newsletter': False, 'notifications': False}
# 368   369   User_369   user369@example.com   20      False  {'newsletter': False, 'notifications': False}
# 369   370   User_370   user370@example.com   46       True   {'newsletter': False, 'notifications': True}
# 370   371   User_371   user371@example.com   49      False   {'newsletter': False, 'notifications': True}
# 371   372   User_372   user372@example.com   57      False   {'newsletter': True, 'notifications': False}
# 372   373   User_373   user373@example.com   56       True   {'newsletter': False, 'notifications': True}
# 373   374   User_374   user374@example.com   59      False  {'newsletter': False, 'notifications': False}
# 374   375   User_375   user375@example.com   59       True    {'newsletter': True, 'notifications': True}
# 375   376   User_376   user376@example.com   38       True    {'newsletter': True, 'notifications': True}
# 376   377   User_377   user377@example.com   39      False    {'newsletter': True, 'notifications': True}
# 377   378   User_378   user378@example.com   54       True  {'newsletter': False, 'notifications': False}
# 378   379   User_379   user379@example.com   53      False    {'newsletter': True, 'notifications': True}
# 379   380   User_380   user380@example.com   43      False   {'newsletter': False, 'notifications': True}
# 380   381   User_381   user381@example.com   18      False   {'newsletter': True, 'notifications': False}
# 381   382   User_382   user382@example.com   30      False   {'newsletter': False, 'notifications': True}
# 382   383   User_383   user383@example.com   35       True  {'newsletter': False, 'notifications': False}
# 383   384   User_384   user384@example.com   43      False   {'newsletter': True, 'notifications': False}
# 384   385   User_385   user385@example.com   36      False   {'newsletter': False, 'notifications': True}
# 385   386   User_386   user386@example.com   55      False   {'newsletter': True, 'notifications': False}
# 386   387   User_387   user387@example.com   60      False    {'newsletter': True, 'notifications': True}
# 387   388   User_388   user388@example.com   30      False   {'newsletter': True, 'notifications': False}
# 388   389   User_389   user389@example.com   45       True   {'newsletter': True, 'notifications': False}
# 389   390   User_390   user390@example.com   29      False    {'newsletter': True, 'notifications': True}
# 390   391   User_391   user391@example.com   18       True  {'newsletter': False, 'notifications': False}
# 391   392   User_392   user392@example.com   60       True   {'newsletter': False, 'notifications': True}
# 392   393   User_393   user393@example.com   45       True  {'newsletter': False, 'notifications': False}
# 393   394   User_394   user394@example.com   24       True  {'newsletter': False, 'notifications': False}
# 394   395   User_395   user395@example.com   48       True   {'newsletter': False, 'notifications': True}
# 395   396   User_396   user396@example.com   25       True   {'newsletter': True, 'notifications': False}
# 396   397   User_397   user397@example.com   39      False   {'newsletter': False, 'notifications': True}
# 397   398   User_398   user398@example.com   45       True   {'newsletter': False, 'notifications': True}
# 398   399   User_399   user399@example.com   59      False    {'newsletter': True, 'notifications': True}
# 399   400   User_400   user400@example.com   39       True    {'newsletter': True, 'notifications': True}
# 400   401   User_401   user401@example.com   36      False    {'newsletter': True, 'notifications': True}
# 401   402   User_402   user402@example.com   18       True   {'newsletter': True, 'notifications': False}
# 402   403   User_403   user403@example.com   48      False  {'newsletter': False, 'notifications': False}
# 403   404   User_404   user404@example.com   33      False   {'newsletter': False, 'notifications': True}
# 404   405   User_405   user405@example.com   54      False  {'newsletter': False, 'notifications': False}
# 405   406   User_406   user406@example.com   35      False  {'newsletter': False, 'notifications': False}
# 406   407   User_407   user407@example.com   39       True    {'newsletter': True, 'notifications': True}
# 407   408   User_408   user408@example.com   59      False   {'newsletter': False, 'notifications': True}
# 408   409   User_409   user409@example.com   57       True    {'newsletter': True, 'notifications': True}
# 409   410   User_410   user410@example.com   24       True   {'newsletter': False, 'notifications': True}
# 410   411   User_411   user411@example.com   47      False   {'newsletter': False, 'notifications': True}
# 411   412   User_412   user412@example.com   20      False   {'newsletter': True, 'notifications': False}
# 412   413   User_413   user413@example.com   42      False    {'newsletter': True, 'notifications': True}
# 413   414   User_414   user414@example.com   22       True    {'newsletter': True, 'notifications': True}
# 414   415   User_415   user415@example.com   52      False   {'newsletter': True, 'notifications': False}
# 415   416   User_416   user416@example.com   20      False  {'newsletter': False, 'notifications': False}
# 416   417   User_417   user417@example.com   26       True    {'newsletter': True, 'notifications': True}
# 417   418   User_418   user418@example.com   39       True  {'newsletter': False, 'notifications': False}
# 418   419   User_419   user419@example.com   18       True    {'newsletter': True, 'notifications': True}
# 419   420   User_420   user420@example.com   25       True  {'newsletter': False, 'notifications': False}
# 420   421   User_421   user421@example.com   19      False  {'newsletter': False, 'notifications': False}
# 421   422   User_422   user422@example.com   50      False    {'newsletter': True, 'notifications': True}
# 422   423   User_423   user423@example.com   46       True   {'newsletter': False, 'notifications': True}
# 423   424   User_424   user424@example.com   53      False   {'newsletter': True, 'notifications': False}
# 424   425   User_425   user425@example.com   56      False   {'newsletter': True, 'notifications': False}
# 425   426   User_426   user426@example.com   28       True    {'newsletter': True, 'notifications': True}
# 426   427   User_427   user427@example.com   23       True  {'newsletter': False, 'notifications': False}
# 427   428   User_428   user428@example.com   55       True   {'newsletter': False, 'notifications': True}
# 428   429   User_429   user429@example.com   48       True   {'newsletter': True, 'notifications': False}
# 429   430   User_430   user430@example.com   49       True    {'newsletter': True, 'notifications': True}
# 430   431   User_431   user431@example.com   23      False   {'newsletter': True, 'notifications': False}
# 431   432   User_432   user432@example.com   54       True    {'newsletter': True, 'notifications': True}
# 432   433   User_433   user433@example.com   60       True    {'newsletter': True, 'notifications': True}
# 433   434   User_434   user434@example.com   21       True   {'newsletter': True, 'notifications': False}
# 434   435   User_435   user435@example.com   48      False    {'newsletter': True, 'notifications': True}
# 435   436   User_436   user436@example.com   46      False    {'newsletter': True, 'notifications': True}
# 436   437   User_437   user437@example.com   46      False  {'newsletter': False, 'notifications': False}
# 437   438   User_438   user438@example.com   36       True  {'newsletter': False, 'notifications': False}
# 438   439   User_439   user439@example.com   18      False   {'newsletter': True, 'notifications': False}
# 439   440   User_440   user440@example.com   47       True  {'newsletter': False, 'notifications': False}
# 440   441   User_441   user441@example.com   21      False    {'newsletter': True, 'notifications': True}
# 441   442   User_442   user442@example.com   51      False   {'newsletter': True, 'notifications': False}
# 442   443   User_443   user443@example.com   19      False    {'newsletter': True, 'notifications': True}
# 443   444   User_444   user444@example.com   19       True   {'newsletter': False, 'notifications': True}
# 444   445   User_445   user445@example.com   36       True   {'newsletter': False, 'notifications': True}
# 445   446   User_446   user446@example.com   31      False    {'newsletter': True, 'notifications': True}
# 446   447   User_447   user447@example.com   20       True   {'newsletter': False, 'notifications': True}
# 447   448   User_448   user448@example.com   44       True   {'newsletter': False, 'notifications': True}
# 448   449   User_449   user449@example.com   60       True    {'newsletter': True, 'notifications': True}
# 449   450   User_450   user450@example.com   48      False  {'newsletter': False, 'notifications': False}
# 450   451   User_451   user451@example.com   57       True    {'newsletter': True, 'notifications': True}
# ...
# 850   851   User_851   user851@example.com   29      False    {'newsletter': True, 'notifications': True}
# 851   852   User_852   user852@example.com   59       True  {'newsletter': False, 'notifications': False}
# 852   853   User_853   user853@example.com   37       True   {'newsletter': True, 'notifications': False}
# 853   854   User_854   user854@example.com   18       True   {'newsletter': False, 'notifications': True}
# 854   855   User_855   user855@example.com   23       True   {'newsletter': True, 'notifications': False}
# 855   856   User_856   user856@example.com   41      False   {'newsletter': True, 'notifications': False}
# 856   857   User_857   user857@example.com   50      False  {'newsletter': False, 'notifications': False}
# 857   858   User_858   user858@example.com   38       True    {'newsletter': True, 'notifications': True}
# 858   859   User_859   user859@example.com   57       True    {'newsletter': True, 'notifications': True}
# 859   860   User_860   user860@example.com   38      False   {'newsletter': True, 'notifications': False}
# 860   861   User_861   user861@example.com   37       True  {'newsletter': False, 'notifications': False}
# 861   862   User_862   user862@example.com   55       True    {'newsletter': True, 'notifications': True}
# 862   863   User_863   user863@example.com   57       True   {'newsletter': False, 'notifications': True}
# 863   864   User_864   user864@example.com   54      False   {'newsletter': True, 'notifications': False}
# 864   865   User_865   user865@example.com   29       True    {'newsletter': True, 'notifications': True}
# 865   866   User_866   user866@example.com   58       True    {'newsletter': True, 'notifications': True}
# 866   867   User_867   user867@example.com   45      False   {'newsletter': False, 'notifications': True}
# 867   868   User_868   user868@example.com   30      False   {'newsletter': True, 'notifications': False}
# 868   869   User_869   user869@example.com   52       True   {'newsletter': True, 'notifications': False}
# 869   870   User_870   user870@example.com   49       True   {'newsletter': False, 'notifications': True}
# 870   871   User_871   user871@example.com   43      False    {'newsletter': True, 'notifications': True}
# 871   872   User_872   user872@example.com   26       True   {'newsletter': False, 'notifications': True}
# 872   873   User_873   user873@example.com   48       True    {'newsletter': True, 'notifications': True}
# 873   874   User_874   user874@example.com   33       True    {'newsletter': True, 'notifications': True}
# 874   875   User_875   user875@example.com   36      False    {'newsletter': True, 'notifications': True}
# 875   876   User_876   user876@example.com   54      False    {'newsletter': True, 'notifications': True}
# 876   877   User_877   user877@example.com   53       True    {'newsletter': True, 'notifications': True}
# 877   878   User_878   user878@example.com   20      False   {'newsletter': True, 'notifications': False}
# 878   879   User_879   user879@example.com   32       True   {'newsletter': False, 'notifications': True}
# 879   880   User_880   user880@example.com   44       True    {'newsletter': True, 'notifications': True}
# 880   881   User_881   user881@example.com   36       True   {'newsletter': True, 'notifications': False}
# 881   882   User_882   user882@example.com   44       True   {'newsletter': True, 'notifications': False}
# 882   883   User_883   user883@example.com   53       True   {'newsletter': True, 'notifications': False}
# 883   884   User_884   user884@example.com   26       True    {'newsletter': True, 'notifications': True}
# 884   885   User_885   user885@example.com   59       True   {'newsletter': False, 'notifications': True}
# 885   886   User_886   user886@example.com   27      False   {'newsletter': True, 'notifications': False}
# 886   887   User_887   user887@example.com   33      False    {'newsletter': True, 'notifications': True}
# 887   888   User_888   user888@example.com   57      False  {'newsletter': False, 'notifications': False}
# 888   889   User_889   user889@example.com   22       True   {'newsletter': True, 'notifications': False}
# 889   890   User_890   user890@example.com   29      False   {'newsletter': False, 'notifications': True}
# 890   891   User_891   user891@example.com   59       True   {'newsletter': True, 'notifications': False}
# 891   892   User_892   user892@example.com   32      False  {'newsletter': False, 'notifications': False}
# 892   893   User_893   user893@example.com   19      False   {'newsletter': True, 'notifications': False}
# 893   894   User_894   user894@example.com   52      False   {'newsletter': False, 'notifications': True}
# 894   895   User_895   user895@example.com   48      False   {'newsletter': True, 'notifications': False}
# 895   896   User_896   user896@example.com   41      False    {'newsletter': True, 'notifications': True}
# 896   897   User_897   user897@example.com   32      False   {'newsletter': True, 'notifications': False}
# 897   898   User_898   user898@example.com   58       True    {'newsletter': True, 'notifications': True}
# 898   899   User_899   user899@example.com   36      False   {'newsletter': True, 'notifications': False}
# 899   900   User_900   user900@example.com   46       True    {'newsletter': True, 'notifications': True}
# 900   901   User_901   user901@example.com   34       True   {'newsletter': False, 'notifications': True}
# 901   902   User_902   user902@example.com   60      False   {'newsletter': False, 'notifications': True}
# 902   903   User_903   user903@example.com   45      False    {'newsletter': True, 'notifications': True}
# 903   904   User_904   user904@example.com   50       True  {'newsletter': False, 'notifications': False}
# 904   905   User_905   user905@example.com   27      False   {'newsletter': True, 'notifications': False}
# 905   906   User_906   user906@example.com   58      False   {'newsletter': False, 'notifications': True}
# 906   907   User_907   user907@example.com   28      False  {'newsletter': False, 'notifications': False}
# 907   908   User_908   user908@example.com   29      False   {'newsletter': False, 'notifications': True}
# 908   909   User_909   user909@example.com   46       True  {'newsletter': False, 'notifications': False}
# 909   910   User_910   user910@example.com   18      False   {'newsletter': False, 'notifications': True}
# 910   911   User_911   user911@example.com   49       True    {'newsletter': True, 'notifications': True}
# 911   912   User_912   user912@example.com   27      False  {'newsletter': False, 'notifications': False}
# 912   913   User_913   user913@example.com   57      False  {'newsletter': False, 'notifications': False}
# 913   914   User_914   user914@example.com   20       True   {'newsletter': True, 'notifications': False}
# 914   915   User_915   user915@example.com   40       True   {'newsletter': False, 'notifications': True}
# 915   916   User_916   user916@example.com   59      False    {'newsletter': True, 'notifications': True}
# 916   917   User_917   user917@example.com   31       True    {'newsletter': True, 'notifications': True}
# 917   918   User_918   user918@example.com   57       True   {'newsletter': True, 'notifications': False}
# 918   919   User_919   user919@example.com   58      False  {'newsletter': False, 'notifications': False}
# 919   920   User_920   user920@example.com   53       True   {'newsletter': False, 'notifications': True}
# 920   921   User_921   user921@example.com   49       True   {'newsletter': False, 'notifications': True}
# 921   922   User_922   user922@example.com   35      False   {'newsletter': True, 'notifications': False}
# 922   923   User_923   user923@example.com   59      False   {'newsletter': False, 'notifications': True}
# 923   924   User_924   user924@example.com   49      False    {'newsletter': True, 'notifications': True}
# 924   925   User_925   user925@example.com   27      False  {'newsletter': False, 'notifications': False}
# 925   926   User_926   user926@example.com   36       True   {'newsletter': True, 'notifications': False}
# 926   927   User_927   user927@example.com   35       True   {'newsletter': True, 'notifications': False}
# 927   928   User_928   user928@example.com   53       True   {'newsletter': True, 'notifications': False}
# 928   929   User_929   user929@example.com   53      False   {'newsletter': False, 'notifications': True}
# 929   930   User_930   user930@example.com   58       True   {'newsletter': True, 'notifications': False}
# 930   931   User_931   user931@example.com   43      False   {'newsletter': True, 'notifications': False}
# 931   932   User_932   user932@example.com   19       True  {'newsletter': False, 'notifications': False}
# 932   933   User_933   user933@example.com   48       True   {'newsletter': True, 'notifications': False}
# 933   934   User_934   user934@example.com   24       True    {'newsletter': True, 'notifications': True}
# 934   935   User_935   user935@example.com   54       True    {'newsletter': True, 'notifications': True}
# 935   936   User_936   user936@example.com   49      False    {'newsletter': True, 'notifications': True}
# 936   937   User_937   user937@example.com   36      False  {'newsletter': False, 'notifications': False}
# 937   938   User_938   user938@example.com   41       True   {'newsletter': False, 'notifications': True}
# 938   939   User_939   user939@example.com   33       True  {'newsletter': False, 'notifications': False}
# 939   940   User_940   user940@example.com   47       True    {'newsletter': True, 'notifications': True}
# 940   941   User_941   user941@example.com   31      False  {'newsletter': False, 'notifications': False}
# 941   942   User_942   user942@example.com   45       True   {'newsletter': False, 'notifications': True}
# 942   943   User_943   user943@example.com   50      False    {'newsletter': True, 'notifications': True}
# 943   944   User_944   user944@example.com   46      False  {'newsletter': False, 'notifications': False}
# 944   945   User_945   user945@example.com   34      False  {'newsletter': False, 'notifications': False}
# 945   946   User_946   user946@example.com   48      False   {'newsletter': True, 'notifications': False}
# 946   947   User_947   user947@example.com   58       True    {'newsletter': True, 'notifications': True}
# 947   948   User_948   user948@example.com   52      False   {'newsletter': False, 'notifications': True}
# 948   949   User_949   user949@example.com   47      False    {'newsletter': True, 'notifications': True}
# 949   950   User_950   user950@example.com   45      False    {'newsletter': True, 'notifications': True}
# 950   951   User_951   user951@example.com   41      False   {'newsletter': False, 'notifications': True}
# 951   952   User_952   user952@example.com   41      False   {'newsletter': False, 'notifications': True}
# 952   953   User_953   user953@example.com   37      False   {'newsletter': True, 'notifications': False}
# 953   954   User_954   user954@example.com   29      False  {'newsletter': False, 'notifications': False}
# 954   955   User_955   user955@example.com   56       True   {'newsletter': True, 'notifications': False}
# 955   956   User_956   user956@example.com   26       True   {'newsletter': False, 'notifications': True}
# 956   957   User_957   user957@example.com   26      False  {'newsletter': False, 'notifications': False}
# 957   958   User_958   user958@example.com   40      False  {'newsletter': False, 'notifications': False}
# 958   959   User_959   user959@example.com   57       True    {'newsletter': True, 'notifications': True}
# 959   960   User_960   user960@example.com   37      False   {'newsletter': False, 'notifications': True}
# 960   961   User_961   user961@example.com   32       True   {'newsletter': False, 'notifications': True}
# 961   962   User_962   user962@example.com   23       True   {'newsletter': False, 'notifications': True}
# 962   963   User_963   user963@example.com   57       True   {'newsletter': True, 'notifications': False}
# 963   964   User_964   user964@example.com   39      False   {'newsletter': True, 'notifications': False}
# 964   965   User_965   user965@example.com   27       True    {'newsletter': True, 'notifications': True}
# 965   966   User_966   user966@example.com   37       True   {'newsletter': True, 'notifications': False}
# 966   967   User_967   user967@example.com   55      False  {'newsletter': False, 'notifications': False}
# 967   968   User_968   user968@example.com   21       True   {'newsletter': False, 'notifications': True}
# 968   969   User_969   user969@example.com   56      False  {'newsletter': False, 'notifications': False}
# 969   970   User_970   user970@example.com   27       True    {'newsletter': True, 'notifications': True}
# 970   971   User_971   user971@example.com   32       True   {'newsletter': False, 'notifications': True}
# 971   972   User_972   user972@example.com   40       True  {'newsletter': False, 'notifications': False}
# 972   973   User_973   user973@example.com   31      False  {'newsletter': False, 'notifications': False}
# 973   974   User_974   user974@example.com   53      False    {'newsletter': True, 'notifications': True}
# 974   975   User_975   user975@example.com   27      False  {'newsletter': False, 'notifications': False}
# 975   976   User_976   user976@example.com   42      False    {'newsletter': True, 'notifications': True}
# 976   977   User_977   user977@example.com   52      False    {'newsletter': True, 'notifications': True}
# 977   978   User_978   user978@example.com   21      False  {'newsletter': False, 'notifications': False}
# 978   979   User_979   user979@example.com   59      False   {'newsletter': True, 'notifications': False}
# 979   980   User_980   user980@example.com   29      False   {'newsletter': True, 'notifications': False}
# 980   981   User_981   user981@example.com   55      False   {'newsletter': False, 'notifications': True}
# 981   982   User_982   user982@example.com   59       True    {'newsletter': True, 'notifications': True}
# 982   983   User_983   user983@example.com   27      False    {'newsletter': True, 'notifications': True}
# 983   984   User_984   user984@example.com   55      False  {'newsletter': False, 'notifications': False}
# 984   985   User_985   user985@example.com   18       True  {'newsletter': False, 'notifications': False}
# 985   986   User_986   user986@example.com   37      False    {'newsletter': True, 'notifications': True}
# 986   987   User_987   user987@example.com   57       True    {'newsletter': True, 'notifications': True}
# 987   988   User_988   user988@example.com   31      False    {'newsletter': True, 'notifications': True}
# 988   989   User_989   user989@example.com   53       True   {'newsletter': False, 'notifications': True}
# 989   990   User_990   user990@example.com   40       True  {'newsletter': False, 'notifications': False}
# 990   991   User_991   user991@example.com   18       True    {'newsletter': True, 'notifications': True}
# 991   992   User_992   user992@example.com   25      False  {'newsletter': False, 'notifications': False}
# 992   993   User_993   user993@example.com   41       True   {'newsletter': False, 'notifications': True}
# 993   994   User_994   user994@example.com   26       True   {'newsletter': False, 'notifications': True}
# 994   995   User_995   user995@example.com   58      False   {'newsletter': False, 'notifications': True}
# 995   996   User_996   user996@example.com   57       True  {'newsletter': False, 'notifications': False}
# 996   997   User_997   user997@example.com   44      False   {'newsletter': True, 'notifications': False}
# 997   998   User_998   user998@example.com   60       True   {'newsletter': True, 'notifications': False}
# 998   999   User_999   user999@example.com   58       True  {'newsletter': False, 'notifications': False}
# 999  1000  User_1000  user1000@example.com   24       True   {'newsletter': False, 'notifications': True}

# %%
df = pd.read_json('data.json')

print(df)
# Out:
#        id       name                 email  age  is_active  \
# 0       1     User_1     user1@example.com   52      False
# 1       2     User_2     user2@example.com   26       True
# 2       3     User_3     user3@example.com   21      False
# 3       4     User_4     user4@example.com   18      False
# 4       5     User_5     user5@example.com   28      False
# ..    ...        ...                   ...  ...        ...
# 995   996   User_996   user996@example.com   57       True
# 996   997   User_997   user997@example.com   44      False
# 997   998   User_998   user998@example.com   60       True
# 998   999   User_999   user999@example.com   58       True
# 999  1000  User_1000  user1000@example.com   24       True
#
#                                        preferences
# 0      {'newsletter': True, 'notifications': True}
# 1      {'newsletter': True, 'notifications': True}
# 2      {'newsletter': True, 'notifications': True}
# 3    {'newsletter': False, 'notifications': False}
# 4     {'newsletter': False, 'notifications': True}
# ..                                             ...
# 995  {'newsletter': False, 'notifications': False}
# 996   {'newsletter': True, 'notifications': False}
# 997   {'newsletter': True, 'notifications': False}
# 998  {'newsletter': False, 'notifications': False}
# 999   {'newsletter': False, 'notifications': True}
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### #Pandas - Analyzing DataFrames

# %% [markdown]
# The head() method returns the headers and a specified number of rows, starting from the top.
# Note: if the number of rows is not specified, the head() method will return the top 5 rows.

# %%
df = pd.read_csv('data.csv')

print(df.head(10))
# Out:
#    ID     Name  Age  Country  Salary   Department
# 0   1   User_1   62      USA   45834      Finance
# 1   2   User_2   59  Germany   46471           HR
# 2   3   User_3   45   Canada   98883  Engineering
# 3   4   User_4   64   Canada   53933           HR
# 4   5   User_5   56      USA   80861           HR
# 5   6   User_6   22   Canada   76241  Engineering
# 6   7   User_7   36    India  112574    Marketing
# 7   8   User_8   18       UK  107533    Marketing
# 8   9   User_9   61      USA   54010        Sales
# 9  10  User_10   30  Germany   96243           HR

# %% [markdown]
# Print the last 5 rows of the DataFrame:

# %%
print(df.tail())
# Out:
#        ID       Name  Age  Country  Salary Department
# 995   996   User_996   46  Germany   86600    Finance
# 996   997   User_997   59   Canada   99839    Finance
# 997   998   User_998   20  Germany   50327      Sales
# 998   999   User_999   34       UK   86632         HR
# 999  1000  User_1000   21       UK  109839  Marketing

# %% [markdown]
# Print information about the data:

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          1000 non-null   int64
#  1   Name        1000 non-null   object
#  2   Age         1000 non-null   int64
#  3   Country     1000 non-null   object
#  4   Salary      1000 non-null   int64
#  5   Department  1000 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 47.0+ KB
# None

# %% [markdown]
# ### Pandas - Cleaning Data

# %% [markdown]
# Return a new Data Frame with no empty cells:
# Notice in the result that some rows have been removed (row 18, 22 and 28).
#
# These rows had cells with empty cells

# %%
df = pd.read_csv('bad_data.csv')

print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# 18        45  2020/12/18     90       112       NaN
# 19        60  2020/12/19    103       123     323.0
# 20        45  2020/12/20     97       125     243.0
# 21        60  2020/12/21    108       131     364.2
# 22        45         NaN    100       119     282.0
# 23        60  2020/12/23    130       101     300.0
# 24        45  2020/12/24    105       132     246.0
# 25        60  2020/12/25    102       126     334.5
# 26        60    20201226    100       120     250.0
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132       NaN
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0

# %%
df = pd.read_csv('bad_data.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# 19        60  2020/12/19    103       123     323.0
# 20        45  2020/12/20     97       125     243.0
# 21        60  2020/12/21    108       131     364.2
# 23        60  2020/12/23    130       101     300.0
# 24        45  2020/12/24    105       132     246.0
# 25        60  2020/12/25    102       126     334.5
# 26        60  2020/12/26    100       120     250.0
# 27        60  2020/12/27     92       118     241.0
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0

# %% [markdown]
# If you want to change the original DataFrame, use the inplace = True argument:

# %%
df = pd.read_csv('bad_data.csv')

# df.dropna(inplace=True)

print(new_df.to_string())

# %% [markdown]
# The fillna() method allows us to replace empty cells with a value:

# %%
df = pd.read_csv('data.csv')

#df.fillna(130, inplace = True)

# %% [markdown]
# Replace NULL values in the "Calories" columns with the number 130:

# %%
df = pd.read_csv('data.csv')

#df.fillna({"Calories": 130}, inplace=True)

# %% [markdown]
# Replace Using Mean, Median, or Mode

# %%
df = pd.read_csv('bad_data.csv')

x = df["Calories"].mean()

df.fillna({"Calories": x})
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130    409.10
# 1         60  2020/12/02    117       145    479.00
# 2         60  2020/12/03    103       135    340.00
# 3         45  2020/12/04    109       175    282.40
# 4         45  2020/12/05    117       148    406.00
# 5         60  2020/12/06    102       127    300.00
# 6         60  2020/12/07    110       136    374.00
# 7        450  2020/12/08    104       134    253.30
# 8         30  2020/12/09    109       133    195.10
# 9         60  2020/12/10     98       124    269.00
# 10        60  2020/12/11    103       147    329.30
# 11        60  2020/12/12    100       120    250.70
# 12        60  2020/12/12    100       120    250.70
# 13        60  2020/12/13    106       128    345.30
# 14        60  2020/12/14    104       132    379.30
# 15        60  2020/12/15     98       123    275.00
# 16        60  2020/12/16     98       120    215.20
# 17        60  2020/12/17    100       120    300.00
# 18        45  2020/12/18     90       112    304.68
# 19        60  2020/12/19    103       123    323.00
# 20        45  2020/12/20     97       125    243.00
# 21        60  2020/12/21    108       131    364.20
# 22        45         NaN    100       119    282.00
# 23        60  2020/12/23    130       101    300.00
# 24        45  2020/12/24    105       132    246.00
# 25        60  2020/12/25    102       126    334.50
# 26        60  2020/12/26    100       120    250.00
# 27        60  2020/12/27     92       118    241.00
# 28        60  2020/12/28    103       132    304.68
# 29        60  2020/12/29    100       132    280.00
# 30        60  2020/12/30    102       129    380.30
# 31        60  2020/12/31     92       115    243.00

# %% [markdown]
# Calculate the MEDIAN, and replace any empty values with it:

# %%
x = df["Calories"].median()

df.fillna({"Calories": x})
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# 18        45  2020/12/18     90       112     291.2
# 19        60  2020/12/19    103       123     323.0
# 20        45  2020/12/20     97       125     243.0
# 21        60  2020/12/21    108       131     364.2
# 22        45         NaN    100       119     282.0
# 23        60  2020/12/23    130       101     300.0
# 24        45  2020/12/24    105       132     246.0
# 25        60  2020/12/25    102       126     334.5
# 26        60  2020/12/26    100       120     250.0
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132     291.2
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0

# %% [markdown]
# Calculate the MODE, and replace any empty values with it:

# %%
x = df["Calories"].mode()[0]

df.fillna({"Calories": x})

# %% [markdown]
# ### Pandas - Cleaning Data of Wrong Format

# %%
df = pd.read_csv("bad_data.csv")

df["Date"] = pd.to_datetime(df["Date"], format='mixed')

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 18        45 2020-12-18     90       112       NaN
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 22        45        NaT    100       119     282.0
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 28        60 2020-12-28    103       132       NaN
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0>

# %% [markdown]
# Remove rows with a NULL value in the "Date" column:

# %%
df.dropna(subset=['Date'])
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 18        45 2020-12-18     90       112       NaN
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 28        60 2020-12-28    103       132       NaN
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0

# %% [markdown]
# ### Pandas - Fixing Wrong Data

# %% [markdown]
# Replacing Values
# Set "Duration" = 45 in row 7:

# %%
df.loc[7, 'Duration'] = 45

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# 18        45 2020-12-18     90       112       NaN
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 22        45        NaT    100       119     282.0
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 28        60 2020-12-28    103       132       NaN
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0>

# %% [markdown]
# Loop through all values in the "Duration" column.
#
# If the value is higher than 120, set it to 120:

# %%
for x in df.index:
    if df.loc[x,"Duration"] > 120:
        df.loc[x,"Duration"] = 120

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        120  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# 18        45  2020/12/18     90       112       NaN
# 19        60  2020/12/19    103       123     323.0
# 20        45  2020/12/20     97       125     243.0
# 21        60  2020/12/21    108       131     364.2
# 22        45         NaN    100       119     282.0
# 23        60  2020/12/23    130       101     300.0
# 24        45  2020/12/24    105       132     246.0
# 25        60  2020/12/25    102       126     334.5
# 26        60    20201226    100       120     250.0
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132       NaN
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0>

# %% [markdown]
# Delete rows where "Duration" is higher than 120:

# %%
for x in df.index:
  if df.loc[x, "Duration"] >= 120:
    df.drop(x, inplace=True)

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# 18        45  2020/12/18     90       112       NaN
# 19        60  2020/12/19    103       123     323.0
# 20        45  2020/12/20     97       125     243.0
# 21        60  2020/12/21    108       131     364.2
# 22        45         NaN    100       119     282.0
# 23        60  2020/12/23    130       101     300.0
# 24        45  2020/12/24    105       132     246.0
# 25        60  2020/12/25    102       126     334.5
# 26        60    20201226    100       120     250.0
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132       NaN
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0>

# %% [markdown]
# Pandas - Removing Duplicates

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# Remove all duplicates:

# %%
df.drop_duplicates(inplace = True)

print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# 18        45  2020/12/18     90       112       NaN
# 19        60  2020/12/19    103       123     323.0
# 20        45  2020/12/20     97       125     243.0
# 21        60  2020/12/21    108       131     364.2
# 22        45         NaN    100       119     282.0
# 23        60  2020/12/23    130       101     300.0
# 24        45  2020/12/24    105       132     246.0
# 25        60  2020/12/25    102       126     334.5
# 26        60    20201226    100       120     250.0
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132       NaN
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0>

# %% [markdown]
# ### Pandas - Data Correlations

# %% [markdown]
# Show the relationship between the columns:

# %%
df = pd.read_csv("new_data1.csv")

df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# Import pyplot from Matplotlib and visualize our DataFrame:

# %%
import matplotlib.pyplot as plt

df = pd.read_csv("new_data1.csv")

df.plot()

plt.show()

# %% [markdown]
# Scatter Plot

# %%
df.plot(kind='scatter', x = 'Duration', y = 'Calories')

plt.show()

# %%
df.plot(kind='scatter', x = 'Duration', y = 'Pulse')

plt.show()

# %% [markdown]
# Histogram
#
# Note: The histogram tells us that there were over 100 workouts that lasted between 50 and 60 minutes.

# %%
df["Duration"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# kind = Line

# %%
df.plot(x='Calories', y='Duration', kind='line')  # For line plot
# Out:
# <Axes: xlabel='Calories'>

# %% [markdown]
# kind = bar

# %%
df.plot(x='Duration', y='Calories', kind='bar')
# Out:
# <Axes: xlabel='Duration'>

# %%
df["Calories"].plot(kind='hist', bins=10, color='skyblue', edgecolor='black')
plt.xlabel("Calories")
plt.ylabel("frequency")
plt.title("Histogram of Duration")
plt.grid(True)
plt.show()
